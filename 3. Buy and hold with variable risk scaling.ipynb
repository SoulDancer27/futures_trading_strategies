# %%
from src import (
    load_simple_price_csv, # used to load simple price data
    VectorizedEngine, # runs the strategy, calculates performance metrics and returns results
    VolatilityScaledBNH, # buy and hold with variable risk scaling
    plot_results # beautiful plot for strategy results
)
import matplotlib.pyplot as plt # used for simple plots

# %%
# 0. Loading data
data = load_simple_price_csv("data/MCFTR.csv", date_format="%Y-%m-%d")
display(data.head())
# Out:
# 2026-06-18 12:15:16.683 | INFO     | src.data.loader:load_simple_price_csv:47 - 📥 Loading simple price data: MCFTR.csv
# 2026-06-18 12:15:16.753 | INFO     | src.data.loader:load_simple_price_csv:81 - ✅ Loaded 5739 bars | Range: 2003-02-26 → 2026-02-13
#              close
# date
# 2003-02-26  335.67
# 2003-02-27  338.35
# 2003-02-28  341.52
# 2003-03-03  352.24
# 2003-03-04  348.40
